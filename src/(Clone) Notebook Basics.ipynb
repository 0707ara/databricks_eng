# %%
print("hellowordl")

# %%
# %run ./includes/setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
files = dbutils.fs.ls("/databricks-datasets")
display(files)
print(files[0].name)
